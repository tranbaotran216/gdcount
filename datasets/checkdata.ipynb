# %%
from fsc147_dataset import FSC147Dataset

dataset = FSC147Dataset(
        ann_path="../data/FSC147/annotation_FSC147_384.json",
        img_root="../data/images_384_VarV2",
        split="train",
        split_file="../data/FSC147/Train_Test_Val_FSC_147.json",
        class_map_file="../data/FSC147/ImageClasses_FSC147.txt",
        img_size=None,
        normalize=True,
        density_root=None,
    )

dataset._load_image_tensor("C:\\Users\\PC\\Documents\\college\\CV\\gdcount_submit\\data\\images_384_VarV2\\3.jpg")
# Out:
# <class 'torch.Tensor'> torch.float32 torch.Size([3, 384, 384])
# <class 'tuple'> 384 384
# (tensor([[[ 1.1358,  1.1529,  1.1700,  ...,  1.1700,  1.2043,  1.2385],
#           [ 1.1358,  1.1529,  1.1700,  ...,  1.1872,  1.2214,  1.2557],
#           [ 1.1358,  1.1529,  1.1700,  ...,  1.2214,  1.2557,  1.2728],
#           ...,
#           [-0.9877, -0.9877, -0.9534,  ..., -1.9980, -2.0152, -2.0152],
#           [-0.9877, -0.9877, -0.9534,  ..., -1.9467, -1.9809, -1.9809],
#           [-0.9877, -0.9877, -0.9534,  ..., -1.9124, -1.9467, -1.9467]],
#
#          [[ 1.3606,  1.3606,  1.3431,  ...,  1.6408,  1.6758,  1.7108],
#           [ 1.3606,  1.3606,  1.3431,  ...,  1.6583,  1.6933,  1.7283],
#           [ 1.3606,  1.3606,  1.3431,  ...,  1.6933,  1.7283,  1.7458],
#           ...,
#           [-1.1429, -1.1429, -1.1078,  ..., -1.8782, -1.8957, -1.8957],
#           [-1.1429, -1.1429, -1.1078,  ..., -1.8256, -1.8606, -1.8606],
# ...

# %%
dataset.__getitem__(0)
# Out:
# <class 'torch.Tensor'> torch.float32 torch.Size([3, 384, 384])
# <class 'tuple'> 384 384
# {'images': tensor([[[ 0.8789,  0.6734,  0.4851,  ..., -0.1143,  0.0056,  0.1254],
#           [ 0.6049,  0.6049,  0.7248,  ...,  0.2111,  0.2282,  0.2967],
#           [ 0.5364,  0.4166,  0.3481,  ...,  0.1254,  0.1083,  0.1426],
#           ...,
#           [ 0.6392,  0.7419,  0.7933,  ...,  1.1187,  1.1187,  1.1187],
#           [ 0.5707,  0.7077,  0.7762,  ...,  1.2899,  1.2899,  1.3242],
#           [ 0.9474,  1.0502,  0.9988,  ...,  1.2557,  1.2043,  1.2214]],
#
#          [[ 0.6078,  0.3978,  0.1877,  ..., -0.4426, -0.3200, -0.1975],
#           [ 0.3277,  0.3277,  0.4328,  ..., -0.1099, -0.0924, -0.0224],
#           [ 0.2577,  0.1352,  0.0476,  ..., -0.2325, -0.2500, -0.2150],
#           ...,
#           [ 0.2927,  0.3978,  0.4503,  ...,  0.7829,  0.7829,  0.7829],
#           [ 0.2227,  0.3627,  0.4328,  ...,  0.9405,  0.9405,  0.9755],
# ...
