# %%
import os
path = r"C:\Users\PC\Documents\college\CV\gdcount\data"
items = os.listdir(path)
print(f"items in folder {path} :")
print(items)
# Out:
# items in folder C:\Users\PC\Documents\college\CV\gdcount\data :
# ['FSC147', 'gt_density_map_adaptive_384_VarV2', 'images_384_VarV2']

# %%
import cv2, numpy, PIL, streamlit
print(f"OpenCV-Python: {cv2.__version__}")
print(f"NumPy: {numpy.__version__}")
print(f"Pillow: {PIL.__version__}")
print(f"Streamlit: {streamlit.__version__}")
# Out:
# OpenCV-Python: 4.12.0
# NumPy: 2.2.6
# Pillow: 12.0.0
# Streamlit: 1.52.1

# %%
# import json

# def list_keys(obj, prefix=""):
#     if isinstance(obj, dict):
#         for k, v in obj.items():
#             print(prefix + k)
#             list_keys(v, prefix + k + ".")
#     elif isinstance(obj, list):
#         for i, item in enumerate(obj):
#             list_keys(item, prefix + f"[{i}].")
# p = r"C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\annotation_FSC147_384.json"
# with open(p, "r", encoding="utf-8") as f:
#     data = json.load(f)

# list_keys(data)

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 3060

# %%
# import matplotlib.pyplot as plt
# import matplotlib.patches as patches
# import numpy as np
# import torch
# import os
# from gdcount.dmodel import GroundingDINOCounter, GDCountConfig
# from gdcount.data_utils import preprocess_inference_image
# import torch

# def denorm_image(img_tensor, mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)):
#     img = img_tensor.clone().cpu().numpy()
#     mean = np.array(mean)[:, None, None]
#     std = np.array(std)[:, None, None]
#     img = img * std + mean
#     img = np.clip(img, 0.0, 1.0)
#     img = np.transpose(img, (1, 2, 0))  # (H,W,3)
#     return img

# def debug_dataset_sample(dataset, idx=None):
#     if idx is None:
#         idx = np.random.randint(0, len(dataset))

#     print(f"=== DEBUG SAMPLE idx = {idx} ===")

#     sample = dataset[idx]

#     img_tensor = sample["image"]
#     text_prompt = sample.get("text", "")
#     exemplar_boxes = sample.get("exemplar_boxes", None)
#     points = sample.get("points", None)
#     gt_count = float(sample.get("count", 0.0))
#     img_id = sample.get("image_id", "")
#     class_name = sample.get("class_name", "")

#     print(f"- image_id: {img_id}")
#     print(f"- class_name: {class_name}")
#     print(f"- text prompt: {repr(text_prompt)}")
#     print(f"- image shape: {tuple(img_tensor.shape)}")
#     print(f"- GT count: {gt_count}")
#     if points is not None:
#         print(f"- num GT points: {points.shape[0]}")
#     if exemplar_boxes is not None:
#         print(f"- num exemplar boxes: {exemplar_boxes.shape[0]}")

#     img_vis = denorm_image(img_tensor)

#     fig, ax = plt.subplots(1, 1, figsize=(6, 6))
#     ax.imshow(img_vis)
#     ax.axis("off")

#     # vẽ exemplar boxes (xanh lá)
#     if exemplar_boxes is not None and isinstance(exemplar_boxes, torch.Tensor) and exemplar_boxes.numel() > 0:
#         boxes_np = exemplar_boxes.cpu().numpy()
#         for (x1, y1, x2, y2) in boxes_np:
#             rect = patches.Rectangle(
#                 (x1, y1),
#                 x2 - x1,
#                 y2 - y1,
#                 linewidth=2,
#                 edgecolor="lime",
#                 facecolor="none",
#             )
#             ax.add_patch(rect)

#     # vẽ GT points (đỏ)
#     if points is not None and isinstance(points, torch.Tensor) and points.numel() > 0:
#         pts_np = points.cpu().numpy()
#         ax.scatter(pts_np[:, 0], pts_np[:, 1], s=10, c="red")

#     title_lines = [f"{img_id}", f"prompt: {text_prompt}", f"GT count: {gt_count}"]
#     ax.set_title("\n".join(title_lines))

#     plt.tight_layout()
#     plt.show()

# %%
from models.gdcount_model import GroundingDINOCounter, GDCountConfig
from gdcount_old.data_utils import preprocess_inference_image
import torch
from torch.utils.data import DataLoader
from datasets.fsc147_dataset import FSC147Dataset, fsc147_collate

device = "cuda" if torch.cuda.is_available() else "cpu"

train_ds = FSC147Dataset(
    ann_path="data/FSC147/annotation_FSC147_384.json",
    img_root="data/images_384_VarV2",                 # hoặc đường dẫn tuyệt đối tới images_384_VarV2
    split="train",
    split_file="data/FSC147/Train_Test_Val_FSC_147.json",
    class_map_file="data/FSC147/ImageClasses_FSC147.txt",
    img_size=None,                                    # nếu dataset của bạn đã resize sẵn 384
    normalize=True,
    density_root=None,
)

train_loader = DataLoader(
    train_ds,
    batch_size=1,
    shuffle=True,
    num_workers=0,
    collate_fn=fsc147_collate,
)

batch = next(iter(train_loader))
print(batch.keys())
print(batch["images"].shape, batch["gt_counts"], batch["prompts"][0])
# Out:
# dict_keys(['images', 'prompts', 'gt_counts', 'meta'])
# torch.Size([1, 3, 384, 683]) tensor([11.]) tomatoes .

# %%
# !python debug_gdcount.py \
  --config "C:/Users/PC/Documents/college/CV/gdcount/groundingdino/groundingdino/config/GroundingDINO_SwinT_OGC.py" \
  --checkpoint "C:/Users/PC/Documents/college/CV/gdcount/weights/groundingdino_swint_ogc.pth" \
  --ann "C:/Users/PC/Documents/college/CV/gdcount/data/FSC147/annotation_FSC147_384.json" \
  --img-root "C:/Users/PC/Documents/college/CV/gdcount/data/images_384_VarV2" \
  --split-file "C:/Users/PC/Documents/college/CV/gdcount/data/FSC147/Train_Test_Val_FSC_147.json" \
  --class-map "C:/Users/PC/Documents/college/CV/gdcount/data/FSC147/ImageClasses_FSC147.txt" \
  --split test \
  --device cuda \
  --soa-level -1 \
  --compare-soa \
  --topk 30 \
  --img-id "5938.jpg" \
  --threshold 0.23
# Out:
# final text_encoder_type: bert-base-uncased
#
# ...
# [PARAM SUMMARY] WITH_SOA (soa_level=-1)
# Total params    : 183,757,763
# Trainable params: 46,755,017
# Frozen params   : 137,002,746
# ------------------------------------------------------------
# SOA params      : 10,917,312 | trainable 10,917,312 | frozen 0
# CountHead params: 769 | trainable 769 | frozen 0
# BaseModel params: 172,839,682 | trainable 35,836,936 | frozen 137,002,746
# Other params    : 0 | trainable 0 | frozen 0
# ...
#
# final text_encoder_type: bert-base-uncased
#
# ...
# [PARAM SUMMARY] NO_SOA (soa_level=None)
# Total params    : 172,840,451
# Trainable params: 35,837,705
# Frozen params   : 137,002,746
# ------------------------------------------------------------
# SOA params      : 0 | trainable 0 | frozen 0
# CountHead params: 769 | trainable 769 | frozen 0
# BaseModel params: 172,839,682 | trainable 35,836,936 | frozen 137,002,746
# Other params    : 0 | trainable 0 | frozen 0
# ...
#
# tensor H,W: 384 577
# ...

# %% [markdown]
# python train_gdcount.py `
#   --config "C:\Users\PC\Documents\college\CV\gdcount\groundingdino\groundingdino\config\GroundingDINO_SwinT_OGC.py" `
#   --checkpoint "C:\Users\PC\Documents\college\CV\gdcount\weights\groundingdino_swint_ogc.pth" `
#   --ann "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\annotation_FSC147_384.json" `
#   --img-root "C:\Users\PC\Documents\college\CV\gdcount\data\images_384_VarV2" `
#   --split-file "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\Train_Test_Val_FSC_147.json" `
#   --class-map "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\ImageClasses_FSC147.txt" `
#   --epochs 50 `
#   --batch-size 1 `
#   --lr 1e-4 `
#   --weight-decay 1e-5 `
#   --device cuda `
#   --log-interval 100 `
#   --save-dir "checkpoints_gdcount" `
#   --no-soa `
#   --freeze-keywords backbone.0 bert `
#   --accum-steps 4 `
#   --exp-name "jitter" `
#   --threshold 0.26 `
#   --nms-iou 0.4

# %% [markdown]
# python test_calib.py `
#   --config "C:\Users\PC\Documents\college\CV\gdcount\groundingdino\groundingdino\config\GroundingDINO_SwinT_OGC.py" `
#   --checkpoint "C:\Users\PC\Documents\college\CV\gdcount\weights\groundingdino_swint_ogc.pth" `
#   --ann "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\annotation_FSC147_384.json" `
#   --img-root "C:\Users\PC\Documents\college\CV\gdcount\data\images_384_VarV2" `
#   --split-file "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\Train_Test_Val_FSC_147.json" `
#   --class-map "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\ImageClasses_FSC147.txt" `
#   --model-ckpt "C:\Users\PC\Documents\college\CV\gdcount\checkpoints_gdcount\text_exemplar_calib\best\gdcount_epoch_013_best.pth" `
#   --batch-size 1 `
#   --use-exemplar `
#   --threshold 0.23 `
#   --nms-iou 0.5 `
#   --log-dir "logs" `
#   --log-file "test_log_calib.csv"

# %% [markdown]
# python test.py `
#   --config "C:\Users\PC\Documents\college\CV\gdcount\groundingdino\groundingdino\config\GroundingDINO_SwinT_OGC.py" `
#   --checkpoint "C:\Users\PC\Documents\college\CV\gdcount\weights\groundingdino_swint_ogc.pth" `
#   --ann "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\annotation_FSC147_384.json" `
#   --img-root "C:\Users\PC\Documents\college\CV\gdcount\data\images_384_VarV2" `
#   --split-file "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\Train_Test_Val_FSC_147.json" `
#   --class-map "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\ImageClasses_FSC147.txt" `
#   --model-ckpt "C:\Users\PC\Documents\college\CV\gdcount\checkpoints_gdcount\text_exemplar_calib\best\gdcount_epoch_013_best.pth" `
#   --batch-size 1

# %% [markdown]
# python finetune_bert.py `
#   --config "C:\Users\PC\Documents\college\CV\gdcount\groundingdino\groundingdino\config\GroundingDINO_SwinT_OGC.py" `
#   --checkpoint "C:\Users\PC\Documents\college\CV\gdcount\weights\groundingdino_swint_ogc.pth" `
#   --ann "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\annotation_FSC147_384.json" `
#   --img-root "C:\Users\PC\Documents\college\CV\gdcount\data\images_384_VarV2" `
#   --split-file "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\Train_Test_Val_FSC_147.json" `
#   --class-map "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\ImageClasses_FSC147.txt" `
#   --epochs 70 `
#   --batch-size 1 `
#   --lr 1e-4 `
#   --bert-lr 2e-6 `
#   --weight-decay 1e-6 `
#   --device cuda `
#   --log-interval 100 `
#   --save-dir "checkpoints_gdcount" `
#   --soa-level -1 `
#   --freeze-keywords backbone.0 bert `
#   --accum-steps 4 `
#   --use-exemplar `
#   --exp-name "finetune_bert_text_exemplar" `
#   --unfreeze-bert-last-n 2 `
#   --nms-iou 0.5 `
#   --resume "C:\Users\PC\Documents\college\CV\gdcount\checkpoints_gdcount\finetune_bert_text_exemplar\best\gdcount_epoch_025_best.pth" `
#   --start-epoch 24

# %% [markdown]
# python train_gdcount.py `
#   --config "C:\Users\PC\Documents\college\CV\gdcount\groundingdino\groundingdino\config\GroundingDINO_SwinT_OGC.py" `
#   --checkpoint "C:\Users\PC\Documents\college\CV\gdcount\weights\groundingdino_swint_ogc.pth" `
#   --ann "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\annotation_FSC147_384.json" `
#   --img-root "C:\Users\PC\Documents\college\CV\gdcount\data\images_384_VarV2" `
#   --split-file "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\Train_Test_Val_FSC_147.json" `
#   --class-map "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\ImageClasses_FSC147.txt" `
#   --epochs 50 `
#   --batch-size 1 `
#   --lr 1e-4 `
#   --weight-decay 1e-5 `
#   --device cuda `
#   --log-interval 100 `
#   --save-dir "checkpoints_gdcount" `
#   --soa-level -1 `
#   --freeze-keywords backbone.0 bert `
#   --accum-steps 4 `
#   --use-exemplar `
#   --exp-name "text_exemplar_calib"

# %%
# !pip list
# Out:
# Package                       Version     Editable project location
# ----------------------------- ----------- ------------------------------------------------------
# addict                        2.4.0
# altair                        5.5.0
# altex                         0.2.0
# asn1crypto                    1.5.1
# asttokens                     3.0.1
# attrs                         25.4.0
# backports.zstd                1.2.0
# beautifulsoup4                4.14.3
# blinker                       1.9.0
# boto3                         1.42.9
# botocore                      1.42.9
# Brotli                        1.2.0
# cachetools                    5.5.2
# certifi                       2025.11.12
# cffi                          2.0.0
# charset-normalizer            3.4.4
# click                         8.3.1
# cloudpickle                   3.1.1
# colorama                      0.4.6
# comm                          0.2.3
# contourpy                     1.3.2
# ...

# %% [markdown]
# Lệnh Test for text_only no exemplar ckpt best/e11

# %% [markdown]
# python test.py `
#   --config "C:\Users\PC\Documents\college\CV\gdcount\groundingdino\groundingdino\config\GroundingDINO_SwinT_OGC.py" `
#   --checkpoint "C:\Users\PC\Documents\college\CV\gdcount\weights\groundingdino_swint_ogc.pth" `
#   --ann "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\annotation_FSC147_384.json" `
#   --img-root "C:\Users\PC\Documents\college\CV\gdcount\data\images_384_VarV2" `
#   --split-file "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\Train_Test_Val_FSC_147.json" `
#   --class-map "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\ImageClasses_FSC147.txt" `
#   --model-ckpt "C:\Users\PC\Documents\college\CV\gdcount\checkpoints_gdcount\jitter\gdcount_epoch_015.pth" `
#   --batch-size 1 `
#   --splits val test `
#   --exp "txt_0nly" `
#   --no-soa `

# %% [markdown]
# python train_gridsearch.py `
#   --config "C:\Users\PC\Documents\college\CV\gdcount\groundingdino\groundingdino\config\GroundingDINO_SwinT_OGC.py" `
#   --checkpoint "C:\Users\PC\Documents\college\CV\gdcount\weights\groundingdino_swint_ogc.pth" `
#   --ann "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\annotation_FSC147_384.json" `
#   --img-root "C:\Users\PC\Documents\college\CV\gdcount\data\images_384_VarV2" `
#   --split-file "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\Train_Test_Val_FSC_147.json" `
#   --class-map "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\ImageClasses_FSC147.txt" `
#   --epochs 50 `
#   --batch-size 1 `
#   --lr 1e-4 `
#   --weight-decay 1e-5 `
#   --device cuda `
#   --log-interval 100 `
#   --save-dir "checkpoints_gdcount" `
#   --soa-level -1 `
#   --freeze-keywords backbone.0 bert `
#   --accum-steps 4 `
#   --exp-name "no_soa_grid" `
#   --tune-threshold `
#   --thr-min 0.05 --thr-max 0.60 --thr-step 0.01

# %%
# !python test_plt_imgs.py \
  --config "C:/Users/PC/Documents/college/CV/gdcount/groundingdino/groundingdino/config/GroundingDINO_SwinT_OGC.py" \
  --checkpoint "C:/Users/PC/Documents/college/CV/gdcount/weights/groundingdino_swint_ogc.pth" \
  --model-ckpt "C:\Users\PC\Documents\college\CV\gdcount\checkpoints_gdcount\text_only\best\gdcount_epoch_015_best.pth" \
  --ann "C:/Users/PC/Documents/college/CV/gdcount/data/FSC147/annotation_FSC147_384.json" \
  --img-root "C:/Users/PC/Documents/college/CV/gdcount/data/images_384_VarV2" \
  --split-file "C:/Users/PC/Documents/college/CV/gdcount/data/FSC147/Train_Test_Val_FSC_147.json" \
  --class-map "C:/Users/PC/Documents/college/CV/gdcount/data/FSC147/ImageClasses_FSC147.txt" \
  --splits test \
  --device cuda \
  --threshold 0.23 \
  --nms-iou 0.5 \
  --sigma 2.0 \
  --alpha 0.75 \
  --pctl 99.0 \
  --gamma 0.45 \
  --out-dir "test_prediction"
# Out:
# Using device: cuda
# final text_encoder_type: bert-base-uncased
# Loaded trained ckpt: C:\Users\PC\Documents\college\CV\gdcount\checkpoints_gdcount\text_only\best\gdcount_epoch_015_best.pth (epoch=15)
# [test] saved: 1190 images -> test_prediction
# Done. Total saved: 1190
# ...
#
# Save [test]:   0%|                                                                             | 0/1190 [00:00<?, ?it/s]FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
# ...
#
# ...
# Save [test]:  54%|████████████████████████████████████▎                              | 645/1190 [01:45<04:19,  2.10it/s]
# ...
# ...
# Save [test]: 100%|██████████████████████████████████████████████████████████████████| 1190/1190 [02:45<00:00,  7.20it/s]

# %%
python train_gdcount.py `
  --config "C:\Users\PC\Documents\college\CV\gdcount\groundingdino\groundingdino\config\GroundingDINO_SwinT_OGC.py" `
  --checkpoint "C:\Users\PC\Documents\college\CV\gdcount\weights\groundingdino_swint_ogc.pth" `
  --ann "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\annotation_FSC147_384.json" `
  --img-root "C:\Users\PC\Documents\college\CV\gdcount\data\images_384_VarV2" `
  --split-file "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\Train_Test_Val_FSC_147.json" `
  --class-map "C:\Users\PC\Documents\college\CV\gdcount\data\FSC147\ImageClasses_FSC147.txt" `
  --epochs 50 `
  --batch-size 1 `
  --lr 1e-4 `
  --weight-decay 1e-5 `
  --device cuda `
  --log-interval 100 `
  --save-dir "checkpoints_gdcount" `
  --no-soa `
  --freeze-keywords backbone.0 bert `
  --accum-steps 4 `
  --exp-name "jitter" `
  --threshold 0.26 `
  --nms-iou 0.4 `
  --side-mode nn `
  --nn-k 0.8 `
  --nn-max-samples 256 `
  --side-jitter-low 0.7 `
  --side-jitter-high 1.4 `
  --side-min 6 `
  --side-max-ratio 0.8 `
  --boost-cnt2-ratio 0.50 `
  --boost-cnt5-ratio 0.35 `
  --resume "C:\Users\PC\Documents\college\CV\gdcount\checkpoints_gdcount\jitter\gdcount_epoch_015.pth" `
  --start-epoch 16

# %%
python train_gdcount.py `
  --config "C:\Users\PC\Documents\college\CV\gdcount_submit\groundingdino\groundingdino\config\GroundingDINO_SwinT_OGC.py" `
  --checkpoint "C:\Users\PC\Documents\college\CV\gdcount_submit\weights\groundingdino_swint_ogc.pth" `
  --data-root "C:\Users\PC\Documents\college\CV\gdcount_submit\data" `
  --epochs 50 `
  --batch-size 1 `
  --lr 1e-4 `
  --weight-decay 1e-5 `
  --device cuda `
  --log-interval 100 `
  --save-dir "checkpoints_gdcount" `
  --no-soa `
  --freeze-keywords backbone.0 bert `
  --accum-steps 4 `
  --threshold 0.26 `
  --nms-iou 0.4 `
  --exp-name "center"
